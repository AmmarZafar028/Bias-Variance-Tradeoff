# %% [markdown]
# #  **Bias-Variance Tradeoff**

# %% [markdown]
# # **1. Introduction**
#
# It’s important to understand prediction errors (bias and variance).There is a tradeoff between a model’s ability to minimize bias and variance. Gaining a proper understanding of these errors would help us not only to build accurate models but also to avoid the mistake of overfitting and underfitting. If our model is too simple and has very few parameters then it may have high bias and low variance. On the other hand if our model has large number of parameters then it's going to have high variance and low bias.

# %% [markdown]
# # 2.  **Understanding Bias**
#
# What is Bias?
# Bias is the difference between the average prediction of our model and the correct value which we are trying to predict. Model with high bias pays very little attention to the training data and oversimplifies the model. It always leads to high error on training and test data.
#
# - Seema Singh

# %% [markdown]
# # Bias Definition in Statistics
#
# In statistics, bias is a term which defines the tendency of the measurement process. It means that it evaluates the over or underestimation of the value of the population parameter. Let us consider an example, in case you have the rule to evaluate the mean of the population. Hopefully, you might have found an estimation using the rule, which is the true reflection of the population. Now, by using the biased estimator, it is easy to find the difference between the true value and the statistically expected value of the population parameter.

# %% [markdown]
# # Why it is so important in Data Science?
# Due to society's culture and history, historical data might be discriminatory against certain minority groups. Cognitive biases are systematic errors in thinking, usually inherited by cultural and personal experiences, that lead to distortions of perceptions when making decisions. And while data might seem objective, data is collected and analyzed by humans, and thus can be biased. Because of this, it's highly important to check assumptions over the data to avoid future algorithmic bias.
#
# Sometimes it can be helpful too!
#
# **The idea of having bias was about model giving importance to some of the features in order to generalize better for the larger dataset with various other attributes. Bias in ML does help us generalize better and make our model less sensitive to some single data point.**
#
# ***Information : Wikipedia, bmc.com, Investopedia, towardsdatascience.***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. **Understanding Variance**
#
# What is **"Variance"**
#
# Variance is a measurement of the spread between numbers in a data set. In probability theory and statistics, variance is the expectation of the squared deviation of a random variable from its population mean or sample mean. Variance is a measure of dispersion, meaning it is a measure of how far a set of numbers is spread out from their average value.
#
#
# # Variance in terms of DS-ML
#
# Variance is the variability of model prediction for a given data point or a value which tells us spread of our data. Model with high variance pays a lot of attention to training data and does not generalize on the data which it hasn’t seen before. As a result, such models perform very well on training data but has high error rates on test data. - Seema Singh
#
# Also, variance refers to the changes in the model when using different portions of the training data set. Simply stated, variance is the variability in the model prediction—how much the ML function can adjust depending on the given data set.
#
# # Measuring Variance
# In statistics, variance measures variability from the average or mean. It is calculated by taking the differences between each number in the data set and the mean, then squaring the differences to make them positive, and finally dividing the sum of the squares by the number of values in the data set.
#
# Bias and variance are used in supervised machine learning, in which an algorithm learns from training data or a sample data set of known quantities. The correct balance of bias and variance is vital to building machine-learning algorithms that create accurate results from their models.
#
#  *Information*: Wikipedia, bmc.com, Investopedia, towardsdatascience.com

# %% [markdown]
# # 4. **Understanding Irreducible error**
#
# This error is out of the control of the machine learning engineer who is building the model. It’s an error caused by noise in the data, random variations that don’t represent a real pattern in the data, or the influence of variables that are not yet captured as features. One way to reduce this type of error is to identify the variables that have impact on the problem we’re modeling and turn them into features.

# %% [markdown]
# # 5.  **Mathematical Explaination**
#
#  Let the variable we are trying to predict as Y and other covariates as X. We assume there is a relationship between the two such that
#
# Y=f(X) + e
#
# Where e is the error term and it’s normally distributed with a mean of 0.
#
# We will make a model f^(X) of f(X) using linear regression or any other modeling technique.
#
# So the expected squared error at a point x is
#
# ![pii.png](data:image/png;base64,...)
#
# The Err(x) can be further decomposed as
#
#
# ![1_e7VaoBh5apjaM2p4afkFyg.png](data:image/png;base64,...)
#
#
# Err(x) is the sum of Bias², variance and the irreducible error.
#
# Irreducible error is the error that can’t be reduced by creating good models. It is a measure of the amount of noise in our data. Here it is important to understand that no matter how good we make our model, our data will have certain amount of noise or irreducible error that can not be removed.
#
# credit -Seema Singh

# %% [markdown]
# # 6. **Bias and Variance using bulls-eye diagram**.
#
# ![pii.png](data:image/png;base64,...)
#
# In the above diagram, center of the target is a model that perfectly predicts correct values. As we move away from the bulls-eye our predictions become get worse and worse. We can repeat our process of model building to get separate hits on the target.
#
# # Underfitting
#
# In supervised learning, underfitting happens when a model unable to capture the underlying pattern of the data. These models usually have high bias and low variance. It happens when we have very less amount of data to build an accurate model or when we try to build a linear model with a nonlinear data. Also, these kind of models are very simple to capture the complex patterns in data like Linear and logistic regression.
#
# # Overfitting
#
# In supervised learning, overfitting happens when our model captures the noise along with the underlying pattern in data. It happens when we train our model a lot over noisy dataset. These models have low bias and high variance. These models are very complex like Decision trees which are prone to overfitting.
#
# ![1_xwtSpR_zg7j7zusa4IDHNQ.png](data:image/png;base64,...)
#
# # Why is Bias Variance Tradeoff?
#
# If our model is too simple and has very few parameters then it may have high bias and low variance. On the other hand if our model has large number of parameters then it’s going to have high variance and low bias. So we need to find the right/good balance without overfitting and underfitting the data.
#
# This tradeoff in complexity is why there is a tradeoff between bias and variance. An algorithm can’t be more complex and less complex at the same time.
#
# ![pic.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 7. **Total Error**
#
# # Total Error = Bias^2 + Variance+ Irreductable Error
# To build a good model, we need to find a good balance between bias and variance such that it minimizes the total error.
#
# An optimal balance of bias and variance would never overfit or underfit the model.
#
# Therefore understanding bias and variance is critical for understanding the behavior of prediction models.
#
# ![pii.png](data:image/png;base64,...)
#
# from Seema Singh

# %% [markdown]
# # 8. **NoteBook Setup**

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import timedelta
import warnings
from scipy import stats
import random
import os
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.express as xp
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Configuration

# %%
warnings.filterwarnings('ignore')
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # 9. **Diving Deep into Code Examples**

# %% [markdown]
# # 9.1.  We Generate Some data

# %%
rows=1000
random_x = np.random.randn(rows)

random_y = (((random_x**5))+ (-2*(random_x**4)) -4.2*(random_x**3)
          +20*(random_x**2) +6**random_x+2).reshape(rows,1)

# %%
random_y.mean()
# Out:
# 19.82766236651594

# %% [markdown]
# # 9.2. We add noise

# %%
mylist =  []

for i in range(0,320):
    x=random.randint(25,100)
    mylist.append(x)

# %%
random_y[0:20] = random_y[0:20]-100
random_y[100:40] = random_y[100:40]-40
random_y[900:920] = random_y[900:920]-20
random_y[200:520] = random_y[200:520]+np.array(mylist).reshape(320,1)
random_y[500:520] = random_y[500:520]-50
random_y[600:640] = random_y[600:640]-40

# %% [markdown]
# # 9.3. Visualizing Distributions oF X and Y

# %%
sns.set(rc = {'figure.figsize':(15,8)})
for i, column in enumerate([random_x,random_y], 1):
    plt.subplot(1, 2, i)
    sns.distplot(column,color ='red',kde = True,bins = 50, fit_kws = {"color": "blue"}, fit= stats.norm,
                 label = "Gamma Distribution")

# %% [markdown]
# # 9.4. Splitting Data into Training and Testing

# %%
# Hold out validation 20% of the data for training

test_size = int(np.round(rows*0.2,0))

# Split the data into train and test
x_train = random_x[:-test_size]
y_train = random_y[:-test_size]
x_test = random_x[-test_size:]
y_test = random_y[-test_size:]

# %% [markdown]
# # 9.5  Plotting the Training Data Set

# %%
fig,ax = plt.subplots(figsize =(15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color ='grey', linestyle ='-', linewidth = 0.25, alpha = 0.5)
ax.scatter(x_train,y_train,color ='red',label ='Train Data')
plt.show()

# %% [markdown]
# ## 10. **Fitting and Developing Linear Regression Model**

# %%
linear_reg_model = np.polyfit(x_train,y_train,deg=1)
linear_model_pred = np.polyval(linear_reg_model,x_test)
linear_model_pred_train = np.polyval(linear_reg_model,x_train)

# %% [markdown]
# #  10.1.  Making Plot with Simple Linear Regression

# %%
fig,ax = plt.subplots(figsize = (15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color ='grey', linestyle ='-', linewidth = 0.25, alpha = 0.5)
ax.scatter(random_x,random_y,color ='blue', linewidth = 5,alpha = 0.5)
plt.plot(x_test,linear_model_pred,color = 'red',label = 'Linear Regression')
plt.show()

# %% [markdown]
# - This is clearly underfits

# %% [markdown]
# # 11.  **Calculating Functions**

# %% [markdown]
# # 11.1 Calculate Bias

# %%
def get_bias(predicted_vales,actual_values):
    return np.round(np.mean(predicted_vales-actual_values)**2,0)

# %% [markdown]
# #  11.2  Calculate Variance

# %%
def get_variance(values):
    return np.round(np.var(values),0)

# %% [markdown]
# #  11.3 Calculate Other Metrices:

# %%
def get_metrics(target_train,target_test,model_train_predictions,model_test_predictions):
    training_mse = mean_squared_error(target_train,model_train_predictions)
    test_mse = mean_squared_error(target_test,model_test_predictions)
    bias = get_bias(model_test_predictions,target_test)
    variance = get_variance(model_test_predictions)
    linear_reg_model = np.polyfit(x_train,y_train,deg=1)
    
    return [training_mse,test_mse,bias,variance]

# %%
degree = []
training_mse = []
test_mse = []
bias = []
variance = []

# %% [markdown]
# # 11.4 Checking Metrics

# %%
# predict values for the training dataset

train_linear_model_predictions = np.polyval(linear_reg_model,x_train)

# predict values for the test dataset

test_model_predictions=np.polyval(linear_reg_model,x_test)

linear_training_mse,linear_test_mse,linear_bias,linear_variance = get_metrics(
    y_train,y_test,train_linear_model_predictions,linear_model_pred)

degree.append(1) 
training_mse.append(linear_training_mse)
test_mse.append(linear_test_mse)
bias.append(linear_bias)
variance.append(linear_variance)

print("Simple Linear Model")
print("Training MSE % 0.f" % linear_training_mse)
print("Test MSE % 0.f" % linear_test_mse)
print("Bias % 0.f" % linear_bias)
print("Variance % 0.f" % linear_variance)
# Out:
# Simple Linear Model
# Training MSE  2646
# Test MSE  997
# Bias  455
# Variance  41

# %% [markdown]
# # 12. **Testing Data with 2nd Degree Polynomial**

# %% [markdown]
# #  12.1 Making Predictions

# %%
poly_2nd_reg_model = np.polyfit(x_train,y_train,deg=2)
poly_2nd = np.poly1d(poly_2nd_reg_model.reshape(1,3)[0])
print("Coefficients %s " % poly_2nd)
# Out:
# Coefficients        2
# 17.66 x + 8.012 x + 23.39

# %%
# predict values for the training dataset
Train_poly_2nd_predictions = np.polyval(poly_2nd_reg_model,x_train)

# predict values for the test dataset
Test_poly_2nd_predictions = np.polyval(poly_2nd_reg_model,x_test)

# %% [markdown]
# # 12.2 Testing Metrics

# %%
poly_2nd_Training_mse,poly_2nd_Test_mse,poly_2nd_bias,poly_2nd_variance = get_metrics(
    y_train,y_test,Train_poly_2nd_predictions,Test_poly_2nd_predictions)

degree.append(2)
training_mse.append(poly_2nd_Training_mse)
test_mse.append(poly_2nd_Test_mse)
bias.append(poly_2nd_bias)
variance.append(poly_2nd_variance)

print("Polynomial 2nd Degree Model")
print("Training MSE % 0.f" % poly_2nd_Training_mse)
print("Test MSE % 0.f" % poly_2nd_Test_mse)
print("Bias % 0.f" % poly_2nd_bias)
print("Variance % 0.f" % poly_2nd_variance)
# Out:
# Polynomial 2nd Degree Model
# Training MSE  2114
# Test MSE  727
# Bias  541
# Variance  669

# %% [markdown]
# #  12.3 Making Plot 2nd Degree polynomial

# %%
fig,ax = plt.subplots(figsize = (15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color ='grey', linestyle ='-', linewidth = 0.25, alpha = 0.5)
x_linspace = np.linspace((random_x.min()),(random_x.max()),num = len(Test_poly_2nd_predictions))
main = ax.scatter(random_x,random_y,color = 'blue', linewidth = 5,alpha = 0.5)
first = plt.plot(x_test,linear_model_pred,color='red',label='Linear Regression')
second = plt.plot(x_linspace,np.polyval(poly_2nd_reg_model,x_linspace),color ='green',label ='Polynomial 2nd Degree')

plt.legend(handles =[main,first[0],second[0]],labels =['Data','Linear Regression','Polynomial 2nd Degree'])
plt.legend()

# %% [markdown]
# - It still underfits

# %% [markdown]
# # 13.  **Testing with 4th Degree Polynomial**

# %% [markdown]
# #  13.1 Making Predictions

# %%
poly_4th_model = np.polyfit(x_train,y_train,deg =4)
poly_4th = np.poly1d(poly_4th_model.reshape(1,5)[0])
print("Coefficients %s " % poly_4th)
# Out:
# Coefficients         4         3         2
# -0.217 x + 8.473 x + 19.23 x - 15.45 x + 22.84

# %%
# predict values for the training dataset
train_poly_4th_pred = np.polyval(poly_4th_model,x_train)

# predict values for the test dataset
test_poly_4th_pred = np.polyval(poly_4th_model,x_test)

# %% [markdown]
# ##  13.2 Testing Metrics

# %%
poly_4th_training_mse,poly_4th_test_mse,poly_4th_bias,poly_4th_variance = get_metrics(
    y_train,y_test,train_poly_4th_pred,test_poly_4th_pred)

degree.append(4)
training_mse.append(poly_4th_training_mse)
test_mse.append(poly_4th_test_mse)
bias.append(poly_4th_bias)
variance.append(poly_4th_variance)


print("Polynomial 4th Degree Model")
print("Training MSE % 0.f" % poly_4th_training_mse)
print("Test MSE % 0.f" % poly_4th_test_mse)
print("Bias % 0.f" % poly_4th_bias)
print("Variance % 0.f" % poly_4th_variance)
# Out:
# Polynomial 4th Degree Model
# Training MSE  1786
# Test MSE  641
# Bias  516
# Variance  906

# %% [markdown]
# # 13.3 Making a Plot

# %%
fig,ax = plt.subplots(figsize = (15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color ='grey', linestyle ='-', linewidth = 0.25, alpha = 0.5)
x_linspace=np.linspace(min(random_x),max(random_x),num = len(test_poly_4th_pred))
main = ax.scatter(random_x,random_y,color='grey', linewidth=5,alpha=0.5)
first = plt.plot(x_test,linear_model_pred,color ='blue',label ='Linear Regression',linewidth =1)
second = plt.plot(x_linspace,np.polyval(poly_2nd,x_linspace),color ='green',label ='Polynomial 2nd Degree',linewidth =1)
fourth = plt.plot(x_linspace,np.polyval(poly_4th,x_linspace),color ='orange',label ='Polynomial 4th Degree',linewidth =3)

plt.legend(fourth[:1],['Polynomial 4th Degree'])

# %% [markdown]
#  - Now its fair fit

# %% [markdown]
# # 14.  **Testing Data  with 5th Degree Polynomial (Original)**

# %% [markdown]
# # 14.1 Making Predictions

# %%
poly_5th_model = np.polyfit(x_train,y_train,deg = 5)
poly_5th = np.poly1d(poly_5th_model.reshape(1,6)[0])

# %%
# predict values for the training dataset
Train_poly_5th_pred = np.polyval(poly_5th_model,x_train)
Test_poly_5th_pred = np.polyval(poly_5th_model,x_test)

# %% [markdown]
# #  14.2 Testing Metrics

# %%
poly_5th_mse_train,poly_5th_mse_test,poly_5th_bias,poly_5th_variance = get_metrics(
    y_train,y_test,Train_poly_5th_pred,Test_poly_5th_pred)

degree.append(5)
training_mse.append(poly_5th_mse_train)
test_mse.append(poly_5th_mse_test)
bias.append(poly_5th_bias)
variance.append(poly_5th_variance)

print("Polynomial 5th Degree Model")
print("Training MSE % 0.f" % poly_5th_mse_train)
print("Test MSE % 0.f" % poly_5th_mse_test)
print("Bias % 0.f" % poly_5th_bias)
print("Variance % 0.f" % poly_5th_variance)
# Out:
# Polynomial 5th Degree Model
# Training MSE  1668
# Test MSE  532
# Bias  488
# Variance  690

# %% [markdown]
# # 14.3 Plotting

# %%
fig,ax = plt.subplots(figsize =(15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color = 'grey', linestyle ='-', linewidth = 0.25, alpha = 0.5)
main=ax.scatter(random_x,random_y,color ='Blue', linewidth = 5,alpha = 0.5)
x_linspace = np.linspace(min(random_x),max(random_x),num = len(test_poly_4th_pred))
first = plt.plot(x_test,linear_model_pred,color ='grey',label = 'Linear Regression',linewidth = 1)
second = plt.plot(x_linspace,np.polyval(poly_2nd,x_linspace),color = 'green',label = 'Polynomial 2nd Degree',linewidth = 1)
fourth = plt.plot(x_linspace,np.polyval(poly_4th,x_linspace),color = 'orange',label='Polynomial 4th Degree',linewidth = 1)
fifth = plt.plot(x_linspace,np.polyval(poly_5th,x_linspace),color = 'red',label='Polynomial 5th Degree',linewidth = 3)

plt.legend(fifth[:1],['Polynomial 5th Degree'])

# %% [markdown]
# - Now This is proper fit

# %% [markdown]
# # 15.  **Testing with 8th Degree Polynomial (Over fit)**

# %% [markdown]
# #  15.1 Making Predictions

# %%
poly_8th_model = np.polyfit(x_train,y_train,deg = 8)
poly_8th = np.poly1d(poly_8th_model.reshape(1,9)[0])

# predict values for the training dataset
Train_poly_8th_pred = np.polyval(poly_8th_model,x_train)
Test_poly_8th_pred = np.polyval(poly_8th_model,x_test)

# %% [markdown]
# # 15.2 Testing Metrics

# %%
poly_8th_training_mse,poly_8th_test_mse,poly_8th_bias,poly_8th_variance = get_metrics(
    y_train,y_test,Train_poly_8th_pred,Test_poly_8th_pred)

degree.append(8)
training_mse.append(poly_8th_training_mse)
test_mse.append(poly_8th_test_mse)
bias.append(poly_8th_bias)
variance.append(poly_8th_variance)

print("Polynomial 8th Degree Model")
print("Training MSE % 0.f" % poly_8th_training_mse)
print("Test MSE % 0.f" % poly_8th_test_mse)
print("Bias % 0.f" % poly_8th_bias)
print("Variance % 0.f" % poly_8th_variance)
# Out:
# Polynomial 8th Degree Model
# Training MSE  1643
# Test MSE  532
# Bias  476
# Variance  651

# %% [markdown]
# # 15.3 Plotting

# %%
fig,ax = plt.subplots(figsize = (15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color = 'grey', linestyle ='-', linewidth = 0.25, alpha = 0.1)
#x.linspace=np.linspace(min(random_x),max(random_x),num=len(Test_poly_8th_pred))
main = ax.scatter(random_x,random_y,color = 'purple', linewidth = 5,alpha = 0.5)
first = plt.plot(x_test,linear_model_pred,color ='grey',label = 'Linear Regression',linewidth = 1)
second = plt.plot(x_linspace,np.polyval(poly_2nd,x_linspace),color ='green',label = 'Polynomial 2nd Degree',linewidth = 1)
fourth = plt.plot(x_linspace,np.polyval(poly_4th,x_linspace),color ='orange',label = 'Polynomial 4th Degree',linewidth = 1)
eight = plt.plot(x_linspace,np.polyval(poly_8th,x_linspace),color ='red',label = 'Polynomial 8th Degree',linewidth = 3)

plt.legend(eight[:1],['Polynomial 8th Degree'])

# %% [markdown]
# # 16. **Testing Polynomial with 70th Degree**

# %% [markdown]
# # 16.1 Making Predictions

# %%
poly_70th_model = np.polyfit(x_train,y_train,deg = 70)
poly_70th = np.poly1d(poly_70th_model.reshape(1,71)[0])
Train_poly_70th_pred = np.polyval(poly_70th_model,x_train)
Test_poly_70th_pred = np.polyval(poly_70th_model,x_test)

# %% [markdown]
# #  16.2 Testing Metrics

# %%
poly_70th_training_mse,poly_70th_test_mse,poly_70th_bias,poly_70th_variance = get_metrics(
    y_train,y_test,Train_poly_70th_pred,Test_poly_70th_pred)

degree.append(70)
training_mse.append(poly_70th_training_mse)
test_mse.append(poly_70th_test_mse)
bias.append(poly_70th_bias)
variance.append(poly_70th_variance)

print("Polynomial 70th Degree Model")
print("Training MSE % 0.f" % poly_70th_training_mse)
print("Test MSE % 0.f" % poly_70th_test_mse)
print("Bias % 0.f" % poly_70th_bias)
print("Variance % 0.f" % poly_70th_variance)
# Out:
# Polynomial 70th Degree Model
# Training MSE  1582
# Test MSE  1477
# Bias  562
# Variance  2318

# %% [markdown]
# # 16.3. Plotting

# %%
fig,ax = plt.subplots(figsize = (15,8))

# Removing the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Adding Major grid lines
ax.grid(color = 'blue', linestyle = '-', linewidth = 0.25, alpha = 0.1)
#x.linspace=np.linspace(min(random_x),max(random_x),num=len(test_poly_4th_pred))
main = ax.scatter(random_x,random_y,color = 'red', linewidth = 5,alpha = 0.5)
first = plt.plot(x_test,linear_model_pred,color ='grey',label ='Linear Regression',linewidth =1)
second = plt.plot(x_linspace,np.polyval(poly_2nd,x_linspace),color ='red',label = 'Polynomial 2nd Degree',linewidth= 1)
fourth = plt.plot(x_linspace,np.polyval(poly_4th,x_linspace),color ='orange',label = 'Polynomial 4th Degree',linewidth =1)
fifth = plt.plot(x_linspace,np.polyval(poly_5th,x_linspace),color = 'green',label = 'Polynomial 5th Degree',linewidth =1)
eight = plt.plot(x_linspace,np.polyval(poly_8th,x_linspace),color = 'blue',label = 'Polynomial 8th Degree',linewidth =1)
seventy = plt.plot(x_linspace,np.polyval(poly_70th,x_linspace),color = 'purple',label = 'Polynomial 70th Degree',linewidth =3)

plt.legend(seventy[:1],['Polynomial 20nd Degree'])

# %% [markdown]
# - Started to over fit

# %% [markdown]
# # 17.  **Plotting Metrics**

# %%
list = [degree,training_mse,test_mse,bias,variance]
df_metrics = pd.DataFrame(list)
df_metrics = df_metrics.T
df_metrics.rename(columns={0:'Degree',1:'Training MSE',2:'Test MSE',3:'Bias',4:'Variance'},inplace = True)
df_metrics
# Out:
#    Degree  Training MSE     Test MSE   Bias  Variance
# 0     1.0   2646.136110   997.102765  455.0      41.0
# 1     2.0   2114.161293   727.452026  541.0     669.0
# 2     4.0   1786.478646   640.557928  516.0     906.0
# 3     5.0   1668.032112   532.265268  488.0     690.0
# 4     8.0   1643.342457   532.447423  476.0     651.0
# 5    70.0   1581.735604  1476.770626  562.0    2318.0

# %%
df_metrics.describe()
# Out:
#           Degree  Training MSE     Test MSE        Bias     Variance
# count   6.000000      6.000000     6.000000    6.000000     6.000000
# mean   15.000000   1906.647704   817.766006  506.333333   879.166667
# std    27.055499    408.945112   365.766440   40.707084   762.299001
# min     1.000000   1581.735604   532.265268  455.000000    41.000000
# 25%     2.500000   1649.514870   559.475050  479.000000   655.500000
# 50%     4.500000   1727.255379   684.004977  502.000000   679.500000
# 75%     7.250000   2032.240631   929.690080  534.750000   852.000000
# max    70.000000   2646.136110  1476.770626  562.000000  2318.000000

# %% [markdown]
# # 17.1. Plotting MSE"s

# %%
plt.figure(figsize = (10,10))
trace1=go.Scatter(x = df_metrics['Degree'],y = df_metrics['Training MSE'],name='Training MSE',
                  line = dict(color = 'red',width = 2),opacity = 0.8,
                  marker = dict(color = 'red',size=10,symbol = 'diamond',line = dict(color = 'red',width =2)))
                  
trace2=go.Scatter(x = df_metrics['Degree'],y = df_metrics['Test MSE'],name = 'Test MSE',
                  line = dict(color = 'blue',width = 2),opacity = 0.8,
                  marker = dict(color ='blue',size=10,symbol = 'diamond',line = dict(color = 'blue',width = 2)))

layout2 = dict(title = 'Mean Squared Error',)
fig2 = dict(data = [trace1,trace2],layout = layout2)
iplot(fig2)
# Out:
# <div>                            <div id="98147fd6-6dd7-4cc8-8314-b96c1dde823b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98147fd6-6dd7-4cc8-8314-b96c1dde823b")) {                    Plotly.newPlot(                        "98147fd6-6dd7-4cc8-8314-b96c1dde823b",                        [{"line":{"color":"red","width":2},"marker":{"color":"red","line":{"color":"red","width":2},"size":10,"symbol":"diamond"},"name":"Training MSE","opacity":0.8,"x":[1.0,2.0,4.0,5.0,8.0,70.0],"y":[2646.136109881099,2114.1612933609686,1786.4786457677817,1668.0321115327142,1643.342456758357,1581.7356037217357],"type":"scatter"},{"line":{"color":"blue","width":2},"marker":{"color":"blue","line":{"color":"blue","width":2},"size":10,"symbol":"diamond"},"name":"Test MSE","
# ...

# %% [markdown]
# # 17.2 Plotting Bias

# %%
plt.figure(figsize = (10,10))
Bias=go.Scatter(x = df_metrics['Degree'],y = df_metrics['Bias'],name = 'Bias',
                line=dict(color = 'red',width =2),opacity = 0.8,
                marker=dict(color = 'red',size = 10,symbol = 'diamond',line = dict(color = 'red',width =2)))

layout2 = dict(title = 'Bias',)
fig=dict(data = [Bias],layout = layout2)
iplot(fig)
# Out:
# <div>                            <div id="a257b05a-e116-4a4b-a662-9cd49fcc346f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a257b05a-e116-4a4b-a662-9cd49fcc346f")) {                    Plotly.newPlot(                        "a257b05a-e116-4a4b-a662-9cd49fcc346f",                        [{"line":{"color":"red","width":2},"marker":{"color":"red","line":{"color":"red","width":2},"size":10,"symbol":"diamond"},"name":"Bias","opacity":0.8,"x":[1.0,2.0,4.0,5.0,8.0,70.0],"y":[455.0,541.0,516.0,488.0,476.0,562.0],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"e
# ...

# %% [markdown]
# # 17.3.  Plotting Variance

# %%
plt.figure(figsize = (15,15))
Variance=go.Scatter(x = df_metrics['Degree'],y = df_metrics['Variance'],name = 'Variance',
                    line = dict(color = 'blue',width = 2),opacity =0.8,
                    marker = dict(color = 'red',size = 10,line = dict(color ='white',width = 10)))

layout2 = dict(title = 'Variance',)
fig=dict(data = [Variance],layout = layout2)
iplot(fig)
# Out:
# <div>                            <div id="ac22719d-3857-4d45-bcad-1d47488c5058" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac22719d-3857-4d45-bcad-1d47488c5058")) {                    Plotly.newPlot(                        "ac22719d-3857-4d45-bcad-1d47488c5058",                        [{"line":{"color":"blue","width":2},"marker":{"color":"red","line":{"color":"white","width":10},"size":10},"name":"Variance","opacity":0.8,"x":[1.0,2.0,4.0,5.0,8.0,70.0],"y":[41.0,669.0,906.0,690.0,651.0,2318.0],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"c
# ...

# %% [markdown]
# # 17.4.  Plotting Bias-Variance

# %%
layout = dict(title = "Bias-Variance Tradeoff",)
fig = dict(data = [Bias,Variance],layout = layout)
iplot(fig)
# Out:
# <div>                            <div id="51ea6e03-eb40-43dd-9859-59c989cd24f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51ea6e03-eb40-43dd-9859-59c989cd24f7")) {                    Plotly.newPlot(                        "51ea6e03-eb40-43dd-9859-59c989cd24f7",                        [{"line":{"color":"red","width":2},"marker":{"color":"red","line":{"color":"red","width":2},"size":10,"symbol":"diamond"},"name":"Bias","opacity":0.8,"x":[1.0,2.0,4.0,5.0,8.0,70.0],"y":[455.0,541.0,516.0,488.0,476.0,562.0],"type":"scatter"},{"line":{"color":"blue","width":2},"marker":{"color":"red","line":{"color":"white","width":10},"size":10},"name":"Variance","opacity":0.8,"x":[1.0,2.0,4.0,5.0,8.0,70.0],"y":[41.0,669.0,906.0,690.0,651.0,2318.0],"type":"scatter"
# ...

# %% [markdown]
# # Reference:
#
# - https://machinelearningmastery.com/gentle-introduction-to-the-bias-variance-trade-off-in-machine-learning/#:~:text=Bias%20is%20the%20simplifying%20assumptions,the%20bias%20and%20the%20variance
#
# - https://towardsdatascience.com/understanding-the-bias-variance-tradeoff-165e6942b229
#
# - https://towardsdatascience.com/bias-variance-tradeoff-in-machine-learning-models-a-practical-example-cf02fb95b15d
#
# - https://towardsdatascience.com/what-bias-variance-bulls-eye-diagram-really-represent-ff6fb9670993
#
# - https://www.mastersindatascience.org/learning/difference-between-bias-and-variance/
